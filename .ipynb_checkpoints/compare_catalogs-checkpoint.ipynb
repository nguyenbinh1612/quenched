# %%
# this sets up basic packages
import numpy as np
import pandas as pd
import astropy.units as u
import astropy.cosmology.units as cu

# this sets up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# this sets up astropy
from astropy.io import fits
from astropy.wcs import WCS
from astropy.wcs.utils import pixel_to_skycoord
from astropy.utils.data import get_pkg_data_filename
from astropy.coordinates import SkyCoord, Angle, match_coordinates_sky, Distance
from astropy.cosmology import Planck15 as cosmo
from astropy.table import Table, unique

from regions import Regions, CircleSkyRegion

# %% [markdown]
# Now, we look at a big catalog from COSMOS-Web, compiled by Hollis Akins.

# %%
# this is the name of the BIG catalog file
large_catalog = '/Users/ngbinh/Downloads/COSMOS-Web_supercatalog_v0.7.fits'

# %%
# this opens the HDU list of the .fits files and asks for the information within. SCI is what we'll use
hdu_list = fits.open(large_catalog)
hdu_list.info()

# this saves the WCS setting to be used later
wcs = WCS(hdu_list[1].header)
# Out:
# Filename: /Users/ngbinh/Downloads/COSMOS-Web_supercatalog_v0.7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    802   913253R x 155C   [K, D, D, 3A, D, 4A, L, D, D, D, D, D, D, D, D, 5D, 5D, 5D, L, D, D, D, D, D, D, D, D, 5D, 5D, 5D, L, D, D, D, D, D, D, D, D, 5D, 5D, 5D, L, D, D, D, D, D, D, D, D, 5D, 5D, 5D, L, D, D, D, D, D, D, D, D, 5D, 5D, 5D, L, D, D, D, D, D, D, D, D, 5D, 5D, 5D, L, K, E, E, K, L, K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, L, K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D]

# %%
# this gets the data of the big catalog. "cat" stands for catalog!
cat_data = hdu_list[1].data

# %%
print(cat_data.columns.names)
# Out:
# ['id', 'ra', 'dec', 'tile', 'chi2_max', 'mode', 'obs_f814w', 'snr_f814w', 'wht_f814w', 'f_auto_f814w', 'e_auto_f814w', 'm_auto_f814w', 'f_seg_f814w', 'e_seg_f814w', 'm_seg_f814w', 'f_aper_f814w', 'e_aper_f814w', 'm_aper_f814w', 'obs_f115w', 'snr_f115w', 'wht_f115w', 'f_auto_f115w', 'e_auto_f115w', 'm_auto_f115w', 'f_seg_f115w', 'e_seg_f115w', 'm_seg_f115w', 'f_aper_f115w', 'e_aper_f115w', 'm_aper_f115w', 'obs_f150w', 'snr_f150w', 'wht_f150w', 'f_auto_f150w', 'e_auto_f150w', 'm_auto_f150w', 'f_seg_f150w', 'e_seg_f150w', 'm_seg_f150w', 'f_aper_f150w', 'e_aper_f150w', 'm_aper_f150w', 'obs_f277w', 'snr_f277w', 'wht_f277w', 'f_auto_f277w', 'e_auto_f277w', 'm_auto_f277w', 'f_seg_f277w', 'e_seg_f277w', 'm_seg_f277w', 'f_aper_f277w', 'e_aper_f277w', 'm_aper_f277w', 'obs_f444w', 'snr_f444w', 'wht_f444w', 'f_auto_f444w', 'e_auto_f444w', 'm_auto_f444w', 'f_seg_f444w', 'e_seg_f444w', 'm_seg_f444w', 'f_aper_f444w', 'e_aper_f444w', 'm_aper_f444w', 'obs_f770w', 'snr_f770w', 'wht_f770w', 'f_auto_f770w', 'e_auto_f770w', 'm_auto_f770w', 'f_seg_f770w', 'e_seg_f770w', 'm_seg_f770w', 'f_aper_f770w', 'e_aper_f770w', 'm_aper_f770w', 'in_spec', 'id_spec', 'match_radius_spec', 'z_spec', 'flag_spec', 'in_sepp', 'id_sepp', 'match_radius_sepp', 'f_sepp_model_hsc_g', 'e_sepp_model_hsc_g', 'f_sepp_model_hsc_r', 'e_sepp_model_hsc_r', 'f_sepp_model_hsc_i', 'e_sepp_model_hsc_i', 'f_sepp_model_hsc_z', 'e_sepp_model_hsc_z', 'f_sepp_model_hsc_y', 'e_sepp_model_hsc_y', 'f_sepp_model_uvista_Y', 'e_sepp_model_uvista_Y', 'f_sepp_model_uvista_J', 'e_sepp_model_uvista_J', 'f_sepp_model_uvista_H', 'e_sepp_model_uvista_H', 'f_sepp_model_uvista_Ks', 'e_sepp_model_uvista_Ks', 'f_sepp_model_f814w', 'e_sepp_model_f814w', 'f_sepp_model_f115w', 'e_sepp_model_f115w', 'f_sepp_model_f150w', 'e_sepp_model_f150w', 'f_sepp_model_f277w', 'e_sepp_model_f277w', 'f_sepp_model_f444w', 'e_sepp_model_f444w', 'f_sepp_model_f770w', 'e_sepp_model_f770w', 'in_primer', 'id_primer', 'match_radius_primer', 'f_primer_auto_f606w', 'e_primer_auto_f606w', 'f_primer_auto_f814w', 'e_primer_auto_f814w', 'f_primer_auto_f090w', 'e_primer_auto_f090w', 'f_primer_auto_f115w', 'e_primer_auto_f115w', 'f_primer_auto_f150w', 'e_primer_auto_f150w', 'f_primer_auto_f200w', 'e_primer_auto_f200w', 'f_primer_auto_f277w', 'e_primer_auto_f277w', 'f_primer_auto_f356w', 'e_primer_auto_f356w', 'f_primer_auto_f410m', 'e_primer_auto_f410m', 'f_primer_auto_f444w', 'e_primer_auto_f444w', 'C_f444w', 'kron_rad', 'kron_pa', 'kron1_a', 'kron1_b', 'kron1_area', 'kron2_a', 'kron2_b', 'kron2_area', 'seg_area', 'kron_corr', 'seg_corr', 'kron_f444w_psf_corr', 'kron_f770w_psf_corr', 'xtra_kron_corr_f770w', 'xtra_seg_corr_f770w']

# %%
# this gets the redshift of all the galaxies
z_spec = cat_data['z_spec']

# %%
# closes the data file
hdu_list.close()

# %%
# create an empty 2D array to put the ID, RA and DEC of galaxies into
big_cat_ra_dec = np.empty(shape=(np.size(cat_data), 3), dtype='float')

# %%
# put the ID, RA and DEC of galaxies in the big catalog into the previously made array
for i in range(np.size(cat_data)):
    ra_dec = np.array(cat_data[i][0:3])
    big_cat_ra_dec[i] = ra_dec

# %%
# this reads in the new confirmed QG catalog and skips the header
df = pd.read_csv('/Users/ngbinh/Downloads/spec_qgs.txt', sep="\s+", header = None, names=['Name', 'RA', 'Dec', 'Redshift'], skiprows=1)

# this saves the data frame as a numpy array of RA and Dec for later usage.
# remember: first column is RA, second is Dec, third is redshift.
spec_qg_ra_dec = df.to_numpy()[1:][:,1:3]
spec_qg_ra_dec = np.vstack(spec_qg_ra_dec).astype(float) # converting dtype from object to float
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/td/xh27mb7x6jz3g1splvmtw7z80000gn/T/ipykernel_1878/1030496139.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('/Users/ngbinh/Downloads/spec_qgs.txt', sep="\s+", header = None, names=['Name', 'RA', 'Dec', 'Redshift'], skiprows=1)

# %%
spec_qg_cat = SkyCoord(ra=spec_qg_ra_dec[:,0]*u.degree, dec=spec_qg_ra_dec[:,1]*u.degree)
all_cat = SkyCoord(ra=big_cat_ra_dec[:,1]*u.degree, dec=big_cat_ra_dec[:,2]*u.degree)

# %%
# now, we search for all the neighbors of the quenched galaxies, within a given distance

dist_new = 1 # trying not to hardcode the distance here just in case we need to change it
idx_spec, idx_maybe, d2d, d3d = all_cat.search_around_sky(spec_qg_cat, dist_new*u.arcsec)
np.all(d2d < dist_new*u.arcsec)
# Out:
# True

# %%
# these are the matches
print(df.loc[idx_spec, "Name"])
# Out:
# 0      ZF-UDS-7329
# 1     ZF-COS-20115
# 17        XMM-2599
# 17        XMM-2599
# 17        XMM-2599
# 20         GS-9209
# 27    3D-UDS-27939
# 28    ZF-COS-20032
# 29    ZF-COS-19589
# 29    ZF-COS-19589
# 30    ZF-COS-18842
# Name: Name, dtype: object

# %% [markdown]
# From this result, we know there are 4 spectroscopically confirmed QGs that are in our catalog: ZF-COS-20115, ZF-COS-20032, ZF-COS-19589 and ZF-COS-18842.

# %%
# now, we get the indices of the galaxies that match (just call them "matches" for now)
matches_idx = np.array([1, 28, 29, 30])

# then, get their RAs, Decs and redshifts
matches_catalog_names = df.loc[matches_idx, "Name"].to_numpy()
matches_ra = df.loc[matches_idx, "RA"].to_numpy() # reminder: unit is in degrees
matches_dec = df.loc[matches_idx, "Dec"].to_numpy() # reminder: unit is in degrees
matches_redshift = df.loc[matches_idx, "Redshift"].to_numpy() * cu.redshift

# %% [markdown]
# New step (May 17, 2024): 5 more quenched galaxies have been discovered. Let's add them!

# %% [markdown]
# From now on, for the sake of memorability, these important quenched galaxies will be named after the rivers of Vietnam. The reason is because Vietnam (my homeland) is a country with MANY, MANY rivers (a limitless source of names), and because galaxies are referred to as "thiên hà" (heavenly rivers) in Vietnamese.

# %%
# new step (May 17, 2024): 5 more quenched galaxies have been discovered. let's add them here
matches_ra = np.concatenate((matches_ra, np.array([150.43732, 150.45459, 150.46120, 150.106932, 150.108873])), axis=0)
matches_dec = np.concatenate((matches_dec, np.array([2.463920, 2.455994, 2.429547, 2.377961, 2.330539])), axis=0)
matches_redshift = np.concatenate((matches_redshift, np.array([3.336, 3.757, 4.673, 4.570, 3.238])), axis=0)

# %%
print(matches_ra, matches_dec, matches_redshift)
# Out:
# [150.06149  150.11256  150.06671  150.08728  150.43732  150.45459
#  150.4612   150.106932 150.108873] [2.37868   2.3765266 2.3823645 2.3960431 2.46392   2.455994  2.429547
#  2.377961  2.330539 ] [3.715 2.474 3.715 3.782 3.336 3.757 4.673 4.57  3.238] redshift

# %%
# let's print out some reminders about the galaxies and their names
matches_names = np.array(['Hong', 'Bach-Dang', 'Gianh', 'Ben-Hai', 'Huong-Giang', 'Thu-Bon', 'Dong-Nai', 'Saigon', 'Tien'])

# %%
matches_cat = SkyCoord(ra=matches_ra*u.degree, dec=matches_dec*u.degree)

# %%
# then, get a corresponding distance from each redshift, and then an angular size
matches_distance = cosmo.kpc_proper_per_arcmin(matches_redshift)
angular_sizes = np.full((1, np.size(matches_names)), 15)[0] * u.arcsec

# %%
### now, loop through each of the matches, use the corresponding angular size
### and search for neighbors within that angular size
which_is_which = []

### this creates a mega list that will be converted into a pandas dataframe
mega_list = []

### this keeps track of the Hollis ID of each object
Hollis_ID_list = []

for galax in range(np.size(matches_names)):
    ### first, call the RA and Dec of the matched QG and its corresponding angular size (aka search radius)
    matches_proper_ra = matches_ra[galax]
    matches_proper_dec = matches_dec[galax]
    matches_ra_dec = matches_cat[galax]
    matches_name = matches_names[galax]
    search_radius = angular_sizes[galax]

    ### now, search for neighbors
    d2d = matches_ra_dec.separation(all_cat)
    catalog_mask = d2d < search_radius
    
    ### now, match the neighbors' indices with their RA and Dec
    matches_near_ra = big_cat_ra_dec[:,1][catalog_mask] # in degrees
    matches_near_dec = big_cat_ra_dec[:,2][catalog_mask] # in degrees
    matches_near_redshift = z_spec[catalog_mask] # no unit

    ### but, unfortunately, these will include the central galaxies themselves, so let's get rid of that
    # first, let's make an empty array of separations
    sep_array = np.zeros(np.size(matches_near_ra))

    # then, use the separation function in astropy to calculate the sky distance between the central galaxy's coords
    # and the coords of each "nearby" galaxy, which now includes the central galaxy and we need to get rid of that
    for j in range(np.size(matches_near_ra)):
        center = SkyCoord(ra=matches_proper_ra*u.degree, dec=matches_proper_dec*u.degree, frame='icrs')
        nearby = SkyCoord(ra=matches_near_ra[j]*u.degree, dec=matches_near_dec[j]*u.degree, frame='fk5')
        sep = center.separation(nearby)
        sep_array[j] = sep.value

    # now, having calculated all the sky distances, we remove the object with the minimum 
    # sky distance/separation, which will correspond to the central galaxy
    matches_near_ra = matches_near_ra[sep_array != min(sep_array)]
    matches_near_dec = matches_near_dec[sep_array != min(sep_array)]
    matches_near_redshift = matches_near_redshift[sep_array != min(sep_array)]

    # now, add the neighbors into a BIG table that we can use to make postage stamps and more
    neighbor_array = np.zeros(np.size(matches_near_ra))
    for idx in range(np.size(matches_near_ra)):
        # first, locate the row that matches the RA and Dec of the neighbor
        neighbor_idx = np.where(cat_data['ra'] == matches_near_ra[idx])
        all_neighbor_data = cat_data[neighbor_idx]

        # this if-statement accounts for duplicate rows by making sure
        # the Hollis ID of each object isn't already added to Hollis_ID_list
        if all_neighbor_data[0][0] not in Hollis_ID_list:
            
            # if the Hollis ID is not in the list, then add to the list to keep track of it
            Hollis_ID_list.append(all_neighbor_data[0][0])
            
            # this adds the neighbor's data into our big list only if the condition is met
            mega_list.append(list(all_neighbor_data[0]))
        
            # this keeps track of which galaxy these neighbors are, well, neighbors of
            which_is_which.append(galax)
    
    # now, subtract to get delta_RA and delta_Dec.
    del_ra_matches = np.abs(matches_proper_ra - matches_near_ra) # in degrees
    del_dec_matches = np.abs(matches_proper_dec - matches_near_dec) # in degrees

    # now, we convert the array from degrees into arcsecs for clarity, then take the vector delta
    del_vector_matches = np.sqrt((del_ra_matches*u.degree.to(u.arcsec))**2 + (del_dec_matches*u.degree.to(u.arcsec))**2)

    # now make histograms summarizing the angular separations
    fig, ax = plt.subplots(1, 1)
    fig.suptitle('neighbors found within ' + str(np.round(search_radius.value, 2)) \
                 + '" of quenched galaxy ' + matches_name) # using "str" to avoid hardcoding
    ax.hist(del_vector_matches) # this converts the array from degrees into arcsecs for clarity
    ax.set(xlabel='angular separation (arcsec)', ylabel='number of neighbors')
    
    fig.savefig('river_hist/hist' + matches_name + '.png')

# %%
# finally, this converts the mega list into a saveable data frame
df_mega = pd.DataFrame(mega_list, columns=cat_data.columns.names)

# %%
df_space = df_mega.assign(our_id=which_is_which)

# %% [markdown]
# NOW! Load a new catalog (Aug 2, 2024) with ground-based data

# %%
# this opens the HDU list of the .fits files and asks for the information within.
new_catalog = Table.read('/Volumes/LaCie/COSMOS_DATA/COSMOSWeb_JAN24_v3.0.0_assoc_cold+hot_sersic_cgs.fits', format='fits')

# %%
### matching coords from the new catalog using SkyCoord 
# create SkyCoord arrays (?) with the RA and Dec of the galaxies in both catalogs
adjusted_cat = SkyCoord(ra=df_space['ra'].values*u.degree, dec=df_space['dec'].values*u.degree)
new_cat = SkyCoord(ra=new_catalog['RA_DETEC']*u.degree, dec=new_catalog['DEC_DETEC']*u.degree)

# use search_around_sky to find matching indices (matching in RA and Dec) in each catalog
idx_adjusted_cat, idx_new_cat, d2d, d3d = new_cat.search_around_sky(adjusted_cat, 1*u.arcsec)

# use the matching indices to the new catalog to see where we have ground-based data of our neighbors
matched_nbrs = new_catalog[idx_new_cat]

# %%
# now, there might be a chance that due to our search radius, one of Hollis's galaxies might get caught
# twice or more by search_around_sky and appears more than once in our matched_nbrs catalog. but we want to
# keep the best match, i.e. the match where the separation (between the RA and Dec in Hollis's catalog vs.
# the RA and Dec in Marko's catalog) is the smallest. so we have to come up with a whole scheme to do it.

# first, we separate the id, which is unique to each galaxy.
# we call the id column, and then only take the unique ids.
matched_ids = matched_nbrs['id'] 
unique_matched_ids = unique(matched_nbrs, keys=['id'], keep='first')['id']

# next, we create a list that we'll fill in with indices to take. these are indices that have either 
# unique ids (i.e. ids that don't repeat) or have repeated ids but also have the smaller/smallest separation.
idx_to_take = []

# now we run a for-loop. this for-loop will go through every single unique id, count the number of times it appears
# in the non-unique array of ids, then find out where the separation is the smallest, then take it
for id in unique_matched_ids:
    
    # this takes the location where the id is unique and there's no duplicate
    if np.size(np.where(matched_ids == id)) == 1:
        idx_to_take.append(np.where(matched_ids == id)[0][0])
        
    # this finds the locations where the id duplicates and takes the location where the separation is minimum
    else:
        separations = d2d[np.where(matched_ids == id)]
        idx_to_take.append(np.where(d2d == min(separations))[0][0])

# %%
# now, this is the REAL list of matched neighbors between Hollis and Marko's catalogs
good_match_nbrs = matched_nbrs[idx_to_take]

# %%
# using the indices we've found in a lot of cells above, we retrieve the ids 
# of the neighbors that do have matches between Hollis and Marko's catalogs.
# the array will be named ids_with_ground because these ids have ground-based detection matches.
ids_with_ground = df_space.iloc[idx_adjusted_cat].iloc[idx_to_take]['id']

# %%
f_ground_cols = [col for col in good_match_nbrs.columns
                 if col.startswith('FLUX_MODEL') and 'FLUX_MODEL_F' not in col and 'FLUX_MODEL_HST' not in col]
e_ground_cols = [col for col in good_match_nbrs.columns
                 if col.startswith('FLUX_ERR_MODEL') and 'FLUX_ERR_MODEL_F' not in col and 'FLUX_ERR_MODEL_HST' not in col]

# %%
# finally, let's put everything into a dictionary and then convert that
# into a mini pandas frame with all the neighbors that has ground-based data
ground_dict = {}

# next, we define all the column names for our upcoming pandas dataframe
ground_column_names = ['id'] + f_ground_cols + e_ground_cols

# now we start populating the dictionary
for idx in range(len(ground_column_names)-1):
    # FIRST, we add the id array
    if idx == 0:
        ground_dict[ground_column_names[idx]] = ids_with_ground.values
    else:
        ground_dict[ground_column_names[idx]] = good_match_nbrs[ground_column_names[idx]].byteswap().newbyteorder()

df_ground = pd.DataFrame(ground_dict)

# %%
df_final = pd.merge(df_space, df_ground, on="id", how="left")

# %%
print(df_final)
# Out:
#           id          ra       dec tile   chi2_max  mode  obs_f814w  \
# 0     756228  150.061200  2.374627   B7  22.734386  cold       True
# 1     756257  150.058961  2.375725   B7  26.606459  cold       True
# 2     756324  150.062186  2.375231   B7  13.810439  cold       True
# 3     756353  150.060723  2.375965   B7  53.525951  cold       True
# 4     756380  150.058538  2.377040   B7  30.541014  cold       True
# ...      ...         ...       ...  ...        ...   ...        ...
# 1021  824190  150.108294  2.334233   B8   7.065062   hot       True
# 1022  824219  150.109404  2.334101   B8   4.507704   hot       True
# 1023  824230  150.108378  2.334557   B8   8.702507   hot       True
# 1024  824244  150.111442  2.333529   B8   7.191070   hot       True
# 1025  824265  150.109179  2.334592   B8   5.532019   hot       True
#
#       snr_f814w      wht_f814w  f_auto_f814w  ...  FLUX_ERR_MODEL_SC-IB427  \
# 0     15.268207   96817.671875      0.067734  ...             4.052830e-31
# 1     15.092929   48639.285156      0.105552  ...             4.862197e-31
# 2      9.004833  116911.343750      0.043047  ...             5.927229e-31
# 3     39.921159   92536.085938      0.242009  ...             9.743410e-31
# 4     24.600919   42102.625000      0.349516  ...             8.863765e-31
# ...         ...            ...           ...  ...                      ...
# 1021   2.335630  168103.546875      0.009100  ...             1.173457e-30
# 1022   0.584582  158324.906250      0.011372  ...                      NaN
# 1023   9.210302  153655.734375      0.009703  ...             3.749612e-31
# 1024  11.800883  159356.718750      0.024322  ...             2.136053e-31
# 1025   4.266627  153827.062500      0.011980  ...             2.169812e-31
#
#       FLUX_ERR_MODEL_SC-IB505  FLUX_ERR_MODEL_SC-IB574  \
# 0                1.919898e-31             7.312176e-31
# 1                2.483323e-31             9.559608e-31
# 2                2.837132e-31             9.679711e-31
# 3                5.179494e-31             2.400348e-30
# 4                4.942317e-31             1.630875e-30
# ...                       ...                      ...
# 1021             6.482673e-31             2.218156e-30
# 1022                      NaN                      NaN
# 1023             2.027641e-31             6.741596e-31
# 1024             1.754584e-31             4.878831e-31
# 1025             1.319702e-31             3.844817e-31
#
#       FLUX_ERR_MODEL_SC-IB709  FLUX_ERR_MODEL_SC-IB827  \
# 0                4.020926e-31             6.659577e-31
# 1                5.230453e-31             6.651084e-31
# 2                6.002242e-31             8.774860e-31
# 3                1.197079e-30             1.584722e-30
# 4                9.884000e-31             1.326599e-30
# ...                       ...                      ...
# 1021             1.264637e-30             1.737856e-30
# 1022                      NaN                      NaN
# 1023             4.747318e-31             5.509084e-31
# 1024             2.703772e-31             3.477351e-31
# 1025             2.183380e-31             3.787556e-31
#
#      FLUX_ERR_MODEL_SC-NB711 FLUX_ERR_MODEL_SC-NB816 FLUX_ERR_MODEL_IRAC-ch1  \
# 0               1.604239e-31            7.726102e-31            1.265058e-31
# 1               2.597503e-31            9.804002e-31            1.776933e-31
# 2               3.057021e-31            1.101882e-30            2.169079e-31
# 3               5.082733e-31            2.006478e-30            3.487428e-31
# 4               3.973796e-31            1.770983e-30            3.692720e-31
# ...                      ...                     ...                     ...
# 1021            5.936484e-31            2.376483e-30            3.157076e-31
# 1022                     NaN                     NaN                     NaN
# 1023            2.002255e-31            7.462639e-31            1.469158e-31
# 1024            9.508817e-32            4.149364e-31            9.628204e-32
# 1025            9.294331e-32            4.189712e-31            9.409777e-32
#
#       FLUX_ERR_MODEL_IRAC-ch2  FLUX_ERR_MODEL_IRAC-ch3
# 0                1.522093e-31             3.649434e-30
# 1                2.029909e-31             4.147804e-30
# 2                1.937569e-31             5.214524e-30
# 3                3.888815e-31             1.134961e-29
# 4                3.974417e-31             7.735101e-30
# ...                       ...                      ...
# 1021             3.838479e-31             1.020703e-29
# 1022                      NaN                      NaN
# 1023             1.937373e-31             4.756795e-30
# 1024             9.624156e-32             3.075707e-30
# 1025             8.918851e-32             2.708806e-30
#
# [1026 rows x 217 columns]

# %%
# this saves the data frame
df_final.to_csv('neighbor_data.csv', index=False)
